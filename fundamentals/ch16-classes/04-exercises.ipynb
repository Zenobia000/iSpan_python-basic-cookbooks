# %% [markdown]
# # Chapter 16: 類別與物件 - 課後習題
#
# 本檔案包含 18 個課後習題，分為三個難度級別：
# - **基礎題（1-8）**：基本類別定義、屬性、方法
# - **進階題（9-14）**：類別屬性、類別方法、物件互動
# - **挑戰題（15-18）**：綜合應用、系統設計
#
# **作答方式**：
# 1. 在每題的 code cell 中撰寫程式碼
# 2. 執行 cell 檢查結果是否符合預期
# 3. 完成後對照 `05-solutions.ipynb` 檢查答案
#
# ---

# %% [markdown]
# ## 📝 基礎題（Basic Level）
#
# ### 練習 1：Rectangle 矩形類別
#
# **題目**：
# 設計一個 `Rectangle` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子接收 `length`（長）和 `width`（寬）
# 2. 提供 `area()` 方法計算面積
# 3. 提供 `perimeter()` 方法計算周長
# 4. 提供 `is_square()` 方法判斷是否為正方形
#
# **測試**：
# ```python
# rect1 = Rectangle(10, 5)
# print(rect1.area())        # 50
# print(rect1.perimeter())   # 30
# print(rect1.is_square())   # False
#
# rect2 = Rectangle(8, 8)
# print(rect2.is_square())   # True
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 2：Circle 圓形類別
#
# **題目**：
# 設計一個 `Circle` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子接收 `radius`（半徑）
# 2. 類別屬性 `PI = 3.14159`
# 3. 提供 `area()` 方法計算面積（π × r²）
# 4. 提供 `circumference()` 方法計算周長（2 × π × r）
# 5. 提供 `diameter()` 方法計算直徑（2 × r）
#
# **測試**：
# ```python
# circle = Circle(5)
# print(f"面積：{circle.area():.2f}")           # 78.54
# print(f"周長：{circle.circumference():.2f}")  # 31.42
# print(f"直徑：{circle.diameter()}")           # 10
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 3：Counter 計數器類別
#
# **題目**：
# 設計一個 `Counter` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子初始化 `count = 0`
# 2. 提供 `increment()` 方法使計數加 1
# 3. 提供 `decrement()` 方法使計數減 1（不能小於 0）
# 4. 提供 `reset()` 方法重設為 0
# 5. 提供 `get_count()` 方法取得當前計數
#
# **測試**：
# ```python
# counter = Counter()
# counter.increment()
# counter.increment()
# counter.increment()
# print(counter.get_count())  # 3
#
# counter.decrement()
# print(counter.get_count())  # 2
#
# counter.reset()
# print(counter.get_count())  # 0
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 4：Book 書籍類別
#
# **題目**：
# 設計一個 `Book` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子接收 `title`（書名）、`author`（作者）、`pages`（頁數）
# 2. 提供 `info()` 方法顯示書籍資訊
# 3. 提供 `is_long_book()` 方法判斷是否超過 500 頁
#
# **測試**：
# ```python
# book = Book("Python 基礎教學", "張小明", 450)
# book.info()
# # 輸出：
# # 書名：Python 基礎教學
# # 作者：張小明
# # 頁數：450 頁
#
# print(book.is_long_book())  # False
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 5：Student 學生類別
#
# **題目**：
# 設計一個 `Student` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子接收 `name`（姓名）、`age`（年齡）
# 2. 建構子初始化 `grades` 為空列表
# 3. 提供 `add_grade(score)` 方法新增成績
# 4. 提供 `get_average()` 方法計算平均分數（無成績回傳 0）
# 5. 提供 `show_report()` 方法顯示學生報告
#
# **測試**：
# ```python
# student = Student("王小明", 18)
# student.add_grade(85)
# student.add_grade(90)
# student.add_grade(88)
# print(f"平均：{student.get_average():.2f}")  # 87.67
# student.show_report()
# # 輸出：
# # 學生：王小明（18 歲）
# # 成績：[85, 90, 88]
# # 平均：87.67 分
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 6：Product 商品類別
#
# **題目**：
# 設計一個 `Product` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子接收 `name`（商品名稱）、`price`（價格）、`quantity`（庫存）
# 2. 提供 `sell(amount)` 方法銷售商品（扣除庫存，庫存不足顯示錯誤）
# 3. 提供 `restock(amount)` 方法補貨（增加庫存）
# 4. 提供 `get_value()` 方法計算總價值（價格 × 庫存）
#
# **測試**：
# ```python
# product = Product("筆記型電腦", 30000, 10)
# product.sell(3)
# print(f"剩餘庫存：{product.quantity}")  # 7
# print(f"庫存價值：{product.get_value()}")  # 210000
#
# product.restock(5)
# print(f"剩餘庫存：{product.quantity}")  # 12
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 7：Temperature 溫度類別
#
# **題目**：
# 設計一個 `Temperature` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子接收 `celsius`（攝氏溫度）
# 2. 提供 `to_fahrenheit()` 方法轉換為華氏溫度（F = C × 9/5 + 32）
# 3. 提供 `to_kelvin()` 方法轉換為絕對溫度（K = C + 273.15）
# 4. 提供 `is_freezing()` 方法判斷是否低於 0°C
# 5. 提供 `is_boiling()` 方法判斷是否高於 100°C
#
# **測試**：
# ```python
# temp = Temperature(25)
# print(f"華氏：{temp.to_fahrenheit()}")  # 77.0
# print(f"絕對溫度：{temp.to_kelvin()}")  # 298.15
# print(temp.is_freezing())  # False
# print(temp.is_boiling())   # False
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 8：Timer 計時器類別
#
# **題目**：
# 設計一個 `Timer` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子初始化 `seconds = 0`
# 2. 提供 `set_time(hours, minutes, seconds)` 方法設定時間（轉換為總秒數）
# 3. 提供 `add_seconds(sec)` 方法增加秒數
# 4. 提供 `get_time()` 方法回傳格式化時間（HH:MM:SS）
#
# **測試**：
# ```python
# timer = Timer()
# timer.set_time(1, 30, 45)  # 1小時30分45秒
# print(timer.get_time())    # "01:30:45"
#
# timer.add_seconds(20)
# print(timer.get_time())    # "01:31:05"
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ## 🔥 進階題（Intermediate Level）
#
# ### 練習 9：BankAccount 銀行帳戶（含類別屬性）
#
# **題目**：
# 設計一個 `BankAccount` 類別，具有以下功能：
#
# **需求**：
# 1. 類別屬性 `interest_rate = 0.02`（年利率 2%）
# 2. 類別屬性 `total_accounts = 0`（追蹤總帳戶數）
# 3. 建構子接收 `owner`（戶名）、`balance`（餘額，預設 0）
# 4. 建構子自動增加 `total_accounts`
# 5. 提供 `deposit(amount)` 存款方法
# 6. 提供 `withdraw(amount)` 提款方法（餘額不足顯示錯誤）
# 7. 提供 `apply_interest()` 方法套用利息（餘額 × 利率）
# 8. 提供類別方法 `set_interest_rate(rate)` 修改利率
#
# **測試**：
# ```python
# account1 = BankAccount("Alice", 1000)
# account2 = BankAccount("Bob", 2000)
# print(f"總帳戶數：{BankAccount.total_accounts}")  # 2
#
# account1.apply_interest()
# print(f"Alice 餘額：{account1.balance}")  # 1020.0
#
# BankAccount.set_interest_rate(0.03)  # 改為 3%
# account2.apply_interest()
# print(f"Bob 餘額：{account2.balance}")  # 2060.0
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 10：Library 圖書館會員計數器
#
# **題目**：
# 設計一個 `LibraryMember` 類別，具有以下功能：
#
# **需求**：
# 1. 類別屬性 `total_members = 0`（總會員數）
# 2. 類別屬性 `borrowed_books = 0`（總借閱數）
# 3. 建構子接收 `name`（會員姓名）、`member_id`（會員編號）
# 4. 建構子初始化 `books_borrowed = 0`（個人借閱數）
# 5. 建構子自動增加 `total_members`
# 6. 提供 `borrow_book()` 方法（增加個人與總借閱數）
# 7. 提供 `return_book()` 方法（減少個人借閱數）
# 8. 提供類別方法 `get_statistics()` 顯示統計資訊
#
# **測試**：
# ```python
# member1 = LibraryMember("Alice", "M001")
# member2 = LibraryMember("Bob", "M002")
#
# member1.borrow_book()
# member1.borrow_book()
# member2.borrow_book()
#
# LibraryMember.get_statistics()
# # 輸出：
# # 總會員數：2
# # 總借閱數：3
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 11：Singleton 單例模式基礎
#
# **題目**：
# 設計一個 `Config` 類別，實作簡單的單例模式（Singleton Pattern）：
#
# **需求**：
# 1. 類別屬性 `_instance = None`（儲存唯一實例）
# 2. 建構子接收 `app_name`（應用程式名稱）
# 3. 提供類別方法 `get_instance(app_name)` 取得實例
#    - 若 `_instance` 為 None，創建新實例
#    - 若已存在，回傳現有實例
# 4. 提供 `show_config()` 方法顯示配置
#
# **測試**：
# ```python
# config1 = Config.get_instance("MyApp")
# config2 = Config.get_instance("MyApp")
#
# print(config1 is config2)  # True（同一個物件）
# config1.show_config()  # 應用程式：MyApp
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 12：Point 點與距離計算
#
# **題目**：
# 設計一個 `Point` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子接收 `x`、`y` 座標
# 2. 提供 `distance_to(other_point)` 方法計算到另一點的距離
#    - 公式：√((x2-x1)² + (y2-y1)²)
# 3. 提供靜態方法 `distance_between(p1, p2)` 計算兩點距離
# 4. 提供 `move(dx, dy)` 方法移動點
#
# **測試**：
# ```python
# p1 = Point(0, 0)
# p2 = Point(3, 4)
#
# print(f"距離：{p1.distance_to(p2)}")  # 5.0
# print(f"距離：{Point.distance_between(p1, p2)}")  # 5.0
#
# p1.move(1, 1)
# print(f"新座標：({p1.x}, {p1.y})")  # (1, 1)
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 13：Time 時間類別（12/24 小時制）
#
# **題目**：
# 設計一個 `Time` 類別，具有以下功能：
#
# **需求**：
# 1. 建構子接收 `hour`、`minute`、`second`（24 小時制）
# 2. 提供 `get_24h_format()` 方法回傳 24 小時制字串（"HH:MM:SS"）
# 3. 提供 `get_12h_format()` 方法回傳 12 小時制字串（"HH:MM:SS AM/PM"）
# 4. 提供類別方法 `from_string(time_str)` 從字串創建時間（"HH:MM:SS"）
# 5. 提供 `add_hours(h)` 方法增加小時數（處理跨日）
#
# **測試**：
# ```python
# time1 = Time(14, 30, 0)
# print(time1.get_24h_format())  # "14:30:00"
# print(time1.get_12h_format())  # "02:30:00 PM"
#
# time2 = Time.from_string("09:15:30")
# print(time2.get_12h_format())  # "09:15:30 AM"
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 14：Pet 寵物類別（物件互動）
#
# **題目**：
# 設計一個 `Pet` 類別，模擬寵物互動：
#
# **需求**：
# 1. 建構子接收 `name`（名字）、`species`（物種）
# 2. 建構子初始化 `hunger = 5`（飢餓度 0-10）、`happiness = 5`（快樂度 0-10）
# 3. 提供 `feed()` 方法餵食（飢餓度 -2，快樂度 +1）
# 4. 提供 `play()` 方法玩耍（快樂度 +2，飢餓度 +1）
# 5. 提供 `interact_with(other_pet)` 方法與其他寵物互動（雙方快樂度 +1）
# 6. 提供 `show_status()` 方法顯示狀態
#
# **測試**：
# ```python
# dog = Pet("旺財", "狗")
# cat = Pet("咪咪", "貓")
#
# dog.feed()
# cat.play()
# dog.interact_with(cat)
#
# dog.show_status()
# # 輸出：
# # 寵物：旺財（狗）
# # 飢餓度：3/10
# # 快樂度：7/10
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ## 💪 挑戰題（Challenge Level）
#
# ### 練習 15：Library 圖書館管理系統
#
# **題目**：
# 設計一個完整的圖書館管理系統，包含 `Book` 和 `Library` 兩個類別：
#
# **Book 類別需求**：
# 1. 建構子接收 `title`、`author`、`isbn`
# 2. 屬性 `is_borrowed = False`（是否被借出）
#
# **Library 類別需求**：
# 1. 建構子初始化 `books = []`（書籍列表）
# 2. 提供 `add_book(book)` 方法新增書籍
# 3. 提供 `borrow_book(isbn)` 方法借書（標記為已借出）
# 4. 提供 `return_book(isbn)` 方法還書（標記為未借出）
# 5. 提供 `find_book(title)` 方法查詢書籍（支援部分比對）
# 6. 提供 `list_available_books()` 方法列出可借書籍
# 7. 提供 `get_statistics()` 方法顯示統計（總書數、已借數、可借數）
#
# **測試**：
# ```python
# library = Library()
# library.add_book(Book("Python 基礎", "張三", "ISBN001"))
# library.add_book(Book("Java 入門", "李四", "ISBN002"))
# library.add_book(Book("Python 進階", "王五", "ISBN003"))
#
# library.borrow_book("ISBN001")
# library.list_available_books()  # 列出 ISBN002、ISBN003
#
# library.find_book("Python")  # 找到兩本 Python 書籍
# library.get_statistics()
# # 輸出：
# # 總書數：3
# # 已借出：1
# # 可借閱：2
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 16：Inventory 庫存管理系統
#
# **題目**：
# 設計一個庫存管理系統，包含 `Product` 和 `Inventory` 兩個類別：
#
# **Product 類別需求**：
# 1. 建構子接收 `product_id`、`name`、`price`、`quantity`
# 2. 提供 `get_value()` 方法計算總價值
# 3. 提供 `update_quantity(delta)` 方法調整庫存（可正可負）
#
# **Inventory 類別需求**：
# 1. 建構子初始化 `products = {}`（字典：product_id → Product）
# 2. 提供 `add_product(product)` 方法新增商品
# 3. 提供 `remove_product(product_id)` 方法移除商品
# 4. 提供 `update_stock(product_id, delta)` 方法調整庫存
# 5. 提供 `get_low_stock(threshold)` 方法取得低庫存商品列表
# 6. 提供 `get_total_value()` 方法計算總庫存價值
# 7. 提供 `generate_report()` 方法生成庫存報告
#
# **測試**：
# ```python
# inventory = Inventory()
# inventory.add_product(Product("P001", "筆記型電腦", 30000, 5))
# inventory.add_product(Product("P002", "滑鼠", 500, 2))
# inventory.add_product(Product("P003", "鍵盤", 1500, 8))
#
# inventory.update_stock("P001", -2)  # 賣出 2 台
# low_stock = inventory.get_low_stock(5)  # 找出庫存 < 5 的商品
# print(f"總價值：${inventory.get_total_value()}")
#
# inventory.generate_report()
# # 輸出完整庫存報告
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 17：Contact 聯絡人管理器
#
# **題目**：
# 設計一個聯絡人管理系統，包含 `Contact` 和 `ContactManager` 兩個類別：
#
# **Contact 類別需求**：
# 1. 建構子接收 `name`、`phone`、`email`、`address`（可選）
# 2. 提供 `update_phone(new_phone)` 方法更新電話
# 3. 提供 `update_email(new_email)` 方法更新信箱
# 4. 提供 `display()` 方法顯示聯絡人資訊
#
# **ContactManager 類別需求**：
# 1. 建構子初始化 `contacts = []`
# 2. 提供 `add_contact(contact)` 方法新增聯絡人
# 3. 提供 `remove_contact(name)` 方法刪除聯絡人
# 4. 提供 `search_by_name(name)` 方法搜尋（支援部分比對）
# 5. 提供 `search_by_phone(phone)` 方法依電話搜尋
# 6. 提供 `list_all()` 方法列出所有聯絡人
# 7. 提供 `get_count()` 方法取得聯絡人總數
#
# **測試**：
# ```python
# manager = ContactManager()
# manager.add_contact(Contact("張三", "0912-345-678", "zhang@email.com"))
# manager.add_contact(Contact("李四", "0923-456-789", "li@email.com"))
# manager.add_contact(Contact("王五", "0934-567-890", "wang@email.com", "台北市"))
#
# result = manager.search_by_name("張")
# result[0].display()
#
# manager.list_all()
# print(f"總聯絡人數：{manager.get_count()}")
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ### 練習 18：TodoList 待辦事項應用
#
# **題目**：
# 設計一個待辦事項應用，包含 `Task` 和 `TodoList` 兩個類別：
#
# **Task 類別需求**：
# 1. 類別屬性 `task_id_counter = 0`（自動產生 ID）
# 2. 建構子接收 `title`、`priority`（"高"/"中"/"低"）
# 3. 建構子自動產生唯一 `task_id`
# 4. 屬性 `is_completed = False`
# 5. 提供 `complete()` 方法標記為完成
# 6. 提供 `display()` 方法顯示任務資訊
#
# **TodoList 類別需求**：
# 1. 建構子初始化 `tasks = []`
# 2. 提供 `add_task(title, priority)` 方法新增任務
# 3. 提供 `complete_task(task_id)` 方法完成任務
# 4. 提供 `remove_task(task_id)` 方法刪除任務
# 5. 提供 `list_pending()` 方法列出未完成任務
# 6. 提供 `list_completed()` 方法列出已完成任務
# 7. 提供 `filter_by_priority(priority)` 方法依優先級過濾
# 8. 提供 `get_statistics()` 方法顯示統計（總數、已完成、待完成）
#
# **測試**：
# ```python
# todo = TodoList()
# todo.add_task("完成 Python 作業", "高")
# todo.add_task("買晚餐", "中")
# todo.add_task("回覆信件", "低")
#
# todo.complete_task(1)
# todo.list_pending()  # 列出待完成任務
#
# high_priority = todo.filter_by_priority("高")
# todo.get_statistics()
# # 輸出：
# # 總任務數：3
# # 已完成：1
# # 待完成：2
# ```

# %%
# 你的程式碼

# %% [markdown]
# ---
#
# ## 🎯 完成檢核
#
# 完成所有習題後，請確認：
#
# ### 基礎題（1-8）
# - [ ] 練習 1：Rectangle 矩形類別
# - [ ] 練習 2：Circle 圓形類別
# - [ ] 練習 3：Counter 計數器類別
# - [ ] 練習 4：Book 書籍類別
# - [ ] 練習 5：Student 學生類別
# - [ ] 練習 6：Product 商品類別
# - [ ] 練習 7：Temperature 溫度類別
# - [ ] 練習 8：Timer 計時器類別
#
# ### 進階題（9-14）
# - [ ] 練習 9：BankAccount 銀行帳戶（含類別屬性）
# - [ ] 練習 10：Library 圖書館會員計數器
# - [ ] 練習 11：Singleton 單例模式基礎
# - [ ] 練習 12：Point 點與距離計算
# - [ ] 練習 13：Time 時間類別（12/24 小時制）
# - [ ] 練習 14：Pet 寵物類別（物件互動）
#
# ### 挑戰題（15-18）
# - [ ] 練習 15：Library 圖書館管理系統
# - [ ] 練習 16：Inventory 庫存管理系統
# - [ ] 練習 17：Contact 聯絡人管理器
# - [ ] 練習 18：TodoList 待辦事項應用
#
# ---
#
# ## 📚 下一步
#
# 1. **對照解答**：參考 `05-solutions.ipynb` 檢查答案
# 2. **自我測驗**：完成 `quiz.ipynb` 驗證學習成果
# 3. **進階學習**：學習 Chapter 17（封裝）、Chapter 18（繼承）
#
# ---
#
# **提示**：
# - 基礎題著重於類別的基本結構與實例方法
# - 進階題涵蓋類別屬性、類別方法、靜態方法
# - 挑戰題需要設計多個類別協作的系統
#
# **加油！** 💪
