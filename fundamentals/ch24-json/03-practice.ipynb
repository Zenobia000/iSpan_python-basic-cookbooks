# %% [markdown]
# # 結構化資料: JSON | Structured Data: JSON
#
# ## 🛠️ 課堂練習 | Practice
#
# ---
#
# ## 📋 練習說明
#
# 本檔案包含 **6 個課堂練習**，用於現場實作，鞏固學習成果。
#
# **建議流程**：
# 1. 閱讀題目要求
# 2. 獨立思考解法
# 3. 實際撰寫程式碼
# 4. 執行測試
# 5. 若遇到困難，可參考 `02-worked-examples.ipynb` 的範例
#
# **預計時間**：30 分鐘
#
# ---

# %% [markdown]
# ## 練習 1：儲存個人資料到JSON檔案
#
# **難度**：基礎 | **主題**：dump基本用法
#
# ### 題目要求
# （詳細需求描述）
#
# ### 提示
# - 提示 1
# - 提示 2

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 2：從JSON讀取並顯示資料
#
# **難度**：基礎 | **主題**：load基本用法
#
# ### 題目要求
# （詳細需求描述）
#
# ### 提示
# - 提示 1
# - 提示 2

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 3：JSON與字串互轉（dumps/loads）
#
# **難度**：基礎 | **主題**：記憶體操作
#
# ### 題目要求
# （詳細需求描述）
#
# ### 提示
# - 提示 1
# - 提示 2

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 4：儲存購物清單到JSON
#
# **難度**：基礎 | **主題**：列表處理
#
# ### 題目要求
# （詳細需求描述）
#
# ### 提示
# - 提示 1
# - 提示 2

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 5：實作通訊錄JSON管理
#
# **難度**：中級 | **主題**：字典操作
#
# ### 題目要求
# （詳細需求描述）
#
# ### 提示
# - 提示 1
# - 提示 2

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 6：格式化輸出JSON（indent=2）
#
# **難度**：中級 | **主題**：美化輸出
#
# ### 題目要求
# （詳細需求描述）
#
# ### 提示
# - 提示 1
# - 提示 2

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
