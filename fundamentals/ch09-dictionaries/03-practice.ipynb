# %% [markdown]
# # Chapter 09: 課堂練習 | In-Class Practice
#
# ---
#
# ## 📋 練習說明
#
# 本檔案包含 **15 題**課堂練習，主題涵蓋：
# - 字典創建（字面量、dict()、fromkeys()、推導式）
# - 字典存取與修改（[]、get()、setdefault()）
# - 字典刪除（del、pop()、popitem()、clear()）
# - 字典方法（keys()、values()、items()、update()）
# - 字典遍歷（鍵、值、鍵值對）
# - 字典推導式應用
# - 巢狀字典設計與操作
#
# **建議完成時間**：60-75 分鐘
#
# **練習方式**：
# 1. 閱讀題目要求
# 2. 在程式碼格子中撰寫程式
# 3. 執行驗證結果
# 4. 對照範例輸出檢查正確性
#
# ---

# %% [markdown]
# ## 練習 1：創建學生資料字典
#
# **難度**：⭐ 基礎
#
# **題目描述**：
# 請創建一個學生資料字典，包含以下鍵值對：
# - name: "Alice"
# - age: 20
# - major: "Computer Science"
# - gpa: 3.8
#
# 然後印出整個字典。
#
# **範例輸出**：
# ```
# {'name': 'Alice', 'age': 20, 'major': 'Computer Science', 'gpa': 3.8}
# ```

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 2：存取字典值
#
# **難度**：⭐ 基礎
#
# **題目描述**：
# 給定一個學生字典，請：
# 1. 使用 `[]` 取得姓名並印出
# 2. 使用 `get()` 取得年齡並印出
# 3. 使用 `get()` 取得不存在的鍵 "grade"，預設值為 "N/A"
#
# **範例輸出**：
# ```
# 姓名: Alice
# 年齡: 20
# 成績: N/A
# ```

# %%
# 給定的字典
student = {"name": "Alice", "age": 20, "major": "CS"}

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 3：修改與新增字典元素
#
# **難度**：⭐ 基礎
#
# **題目描述**：
# 給定一個學生字典，請：
# 1. 將年齡修改為 21
# 2. 新增一個鍵 "grade"，值為 "A"
# 3. 印出修改後的字典
#
# **範例輸出**：
# ```
# {'name': 'Alice', 'age': 21, 'major': 'CS', 'grade': 'A'}
# ```

# %%
# 給定的字典
student = {"name": "Alice", "age": 20, "major": "CS"}

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 4：使用 fromkeys() 創建字典
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 給定一個水果列表 `["apple", "banana", "cherry"]`，請使用 `dict.fromkeys()` 創建一個字典，所有鍵的初始值為 0，代表庫存數量。
#
# **範例輸出**：
# ```
# {'apple': 0, 'banana': 0, 'cherry': 0}
# ```

# %%
# 給定的水果列表
fruits = ["apple", "banana", "cherry"]

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 5：刪除字典元素
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 給定一個字典，請：
# 1. 使用 `del` 刪除鍵 "major"
# 2. 使用 `pop()` 刪除鍵 "age" 並印出被刪除的值
# 3. 印出刪除後的字典
#
# **範例輸出**：
# ```
# 刪除的年齡: 20
# 剩餘資料: {'name': 'Alice', 'grade': 'A'}
# ```

# %%
# 給定的字典
student = {"name": "Alice", "age": 20, "major": "CS", "grade": "A"}

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 6：遍歷字典的鍵
#
# **難度**：⭐ 基礎
#
# **題目描述**：
# 給定一個學生成績字典，請遍歷所有的鍵（學生姓名），並逐一印出。
#
# **範例輸出**：
# ```
# 學生姓名:
# Alice
# Bob
# Charlie
# ```

# %%
# 給定的字典
scores = {"Alice": 85, "Bob": 92, "Charlie": 78}

# 在此撰寫你的程式碼
print("學生姓名:")

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 7：遍歷字典的鍵值對
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 給定一個學生成績字典，請遍歷所有鍵值對，並以「姓名: 分數」格式印出。
#
# **範例輸出**：
# ```
# Alice: 85 分
# Bob: 92 分
# Charlie: 78 分
# ```

# %%
# 給定的字典
scores = {"Alice": 85, "Bob": 92, "Charlie": 78}

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 8：計算字典值的總和與平均
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 給定一個學生成績字典，請計算並印出：
# 1. 總分
# 2. 平均分數（保留 2 位小數）
#
# **提示**：使用 `values()` 方法和 `sum()` 函式。
#
# **範例輸出**：
# ```
# 總分: 255
# 平均: 85.00
# ```

# %%
# 給定的字典
scores = {"Alice": 85, "Bob": 92, "Charlie": 78}

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 9：使用 update() 合併字典
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 給定兩個字典 `student1` 和 `new_info`，請使用 `update()` 方法將 `new_info` 合併到 `student1`，並印出合併後的結果。
#
# **範例輸出**：
# ```
# {'name': 'Alice', 'age': 21, 'major': 'CS', 'grade': 'A', 'gpa': 3.8}
# ```

# %%
# 給定的字典
student1 = {"name": "Alice", "age": 20, "major": "CS"}
new_info = {"age": 21, "grade": "A", "gpa": 3.8}

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 10：字典推導式 - 數字平方
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 請使用字典推導式創建一個字典，鍵為 1-10 的整數，值為該數字的平方。
#
# **範例輸出**：
# ```
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# ```

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 11：字典推導式 - 篩選及格學生
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 給定一個學生成績字典，請使用字典推導式創建一個新字典，只包含分數 >= 80 的學生。
#
# **範例輸出**：
# ```
# {'Alice': 85, 'Bob': 92, 'David': 88}
# ```

# %%
# 給定的字典
scores = {"Alice": 85, "Bob": 92, "Charlie": 78, "David": 88, "Eve": 65}

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 12：字元頻率統計
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 給定一個字串，請寫一個程式統計每個字元（不包含空格）出現的次數，並儲存在字典中。
#
# **提示**：使用 `get()` 方法或 `setdefault()` 方法。
#
# **範例輸出**：
# ```
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, 'w': 1, 'r': 1, 'd': 1}
# ```

# %%
# 給定的字串
text = "hello world"

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 13：巢狀字典 - 創建與存取
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 請創建一個巢狀字典來儲存兩位學生的資料，每位學生包含姓名、年齡和成績字典（數學、英文）。
#
# 然後：
# 1. 印出 Alice 的數學成績
# 2. 印出 Bob 的英文成績
#
# **範例資料**：
# - Alice: 年齡 20，數學 85，英文 90
# - Bob: 年齡 21，數學 92，英文 88
#
# **範例輸出**：
# ```
# Alice 的數學成績: 85
# Bob 的英文成績: 88
# ```

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 14：巢狀字典 - 計算平均分數
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 給定一個巢狀字典（學生資料，包含姓名和成績字典），請遍歷所有學生，計算並印出每位學生的平均分數。
#
# **範例輸出**：
# ```
# Alice 的平均分數: 87.50
# Bob 的平均分數: 90.00
# ```

# %%
# 給定的巢狀字典
students = {
    "S001": {
        "name": "Alice",
        "scores": {"math": 85, "english": 90}
    },
    "S002": {
        "name": "Bob",
        "scores": {"math": 92, "english": 88}
    }
}

# 在此撰寫你的程式碼

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 15：綜合應用 - 簡易通訊錄
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 請使用字典設計一個簡易通訊錄，並實作以下功能：
#
# 1. 新增聯絡人：新增 3 個聯絡人（姓名、電話、email）
# 2. 查詢聯絡人：根據姓名查詢電話
# 3. 更新電話：將某位聯絡人的電話更新
# 4. 刪除聯絡人：刪除某位聯絡人
# 5. 顯示所有聯絡人：列出所有人的姓名和電話
#
# **範例輸出**：
# ```
# === 新增聯絡人 ===
# 已新增: Alice
# 已新增: Bob
# 已新增: Charlie
#
# === 查詢聯絡人 ===
# Alice 的電話: 0912-345-678
#
# === 更新電話 ===
# 已更新 Alice 的電話為: 0987-654-321
#
# === 刪除聯絡人 ===
# 已刪除: Charlie
#
# === 所有聯絡人 ===
# Alice: 0987-654-321
# Bob: 0923-456-789
# ```

# %%
# 在此撰寫你的程式碼

# 初始化通訊錄
contacts = {}

# 1. 新增聯絡人
print("=== 新增聯絡人 ===")


# 2. 查詢聯絡人
print("\n=== 查詢聯絡人 ===")


# 3. 更新電話
print("\n=== 更新電話 ===")


# 4. 刪除聯絡人
print("\n=== 刪除聯絡人 ===")


# 5. 顯示所有聯絡人
print("\n=== 所有聯絡人 ===")

# %% [markdown]
# ---
#
# ## 🎉 練習完成！
#
# 完成所有練習後，請：
# 1. 檢查輸出是否符合範例
# 2. 嘗試修改資料，測試不同情況
# 3. 理解每個字典方法的用途
# 4. 繼續挑戰 `04-exercises.ipynb` 課後習題
#
# ---
