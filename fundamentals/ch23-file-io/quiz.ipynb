# %% [markdown]
# # Ch23: 檔案輸入輸出基礎 - 自我測驗
#
# 本測驗包含 **25 題**，涵蓋 Ch23 所有核心概念。
#
# ## 測驗說明
# - **Part I: 選擇題（15 題）** - 每題 1 分，共 15 分
# - **Part II: 程式碼輸出題（5 題）** - 每題 2 分，共 10 分
# - **Part III: 程式碼填空題（5 題）** - 每題 3 分，共 15 分
# - **總分：40 分** | **及格：30 分 (75%)**
#
# **建議時間**：30 分鐘
#
# ---

# %% [markdown]
# ## Part I: 選擇題（15 分）
#
# 請選擇最適合的答案。
#
# ---

# %% [markdown]
# ### 第 1 題（1 分）
#
# 以下哪個模式會**覆蓋**現有檔案的內容？
#
# (A) `'r'`
# (B) `'w'`
# (C) `'a'`
# (D) `'x'`
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 2 題（1 分）
#
# `with open('file.txt', 'r') as f:` 語句的主要優點是？
#
# (A) 讀取速度更快
# (B) 自動關閉檔案
# (C) 可以同時開啟多個檔案
# (D) 支援更多編碼格式
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 3 題（1 分）
#
# 以下哪個方法會返回**列表**，每個元素是檔案的一行？
#
# (A) `read()`
# (B) `readline()`
# (C) `readlines()`
# (D) `readall()`
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 4 題（1 分）
#
# 若要在檔案末尾**附加**內容，應使用哪個模式？
#
# (A) `'r'`
# (B) `'w'`
# (C) `'a'`
# (D) `'r+'`
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 5 題（1 分）
#
# 以下程式碼的輸出是什麼？
#
# ```python
# with open('test.txt', 'w') as f:
#     f.write('Hello')
#     f.write('World')
# ```
#
# 檔案 `test.txt` 的內容為：
#
# (A) `Hello World`
# (B) `HelloWorld`
# (C) `Hello\nWorld`
# (D) 會產生錯誤
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 6 題（1 分）
#
# 讀取文字檔案時，若不指定 `encoding` 參數，Python 會使用什麼編碼？
#
# (A) UTF-8
# (B) ASCII
# (C) 系統預設編碼
# (D) Big5
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 7 題（1 分）
#
# 以下哪個方法**不會**自動加上換行符號？
#
# (A) `print()`
# (B) `write()`
# (C) `writelines()`
# (D) B 和 C
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 8 題（1 分）
#
# 嘗試開啟不存在的檔案時（使用 `'r'` 模式），會發生什麼？
#
# (A) 自動建立新檔案
# (B) 返回 `None`
# (C) 拋出 `FileNotFoundError`
# (D) 拋出 `IOError`
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 9 題（1 分）
#
# 以下哪個編碼**不**支援繁體中文？
#
# (A) UTF-8
# (B) Big5
# (C) ASCII
# (D) GBK
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 10 題（1 分）
#
# 使用 `f.read()` 讀取檔案後，檔案指標的位置在哪裡？
#
# (A) 檔案開頭
# (B) 檔案中間
# (C) 檔案結尾
# (D) 不變
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 11 題（1 分）
#
# 以下哪個方法可以**逐行迭代**檔案內容（記憶體效率最高）？
#
# (A) `f.read().split('\n')`
# (B) `f.readlines()`
# (C) `for line in f:`
# (D) `f.readline()`
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 12 題（1 分）
#
# `writelines()` 方法接受什麼類型的參數？
#
# (A) 字串
# (B) 列表或可迭代物件
# (C) 字典
# (D) 整數
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 13 題（1 分）
#
# 以下哪個模式可以**同時讀寫**檔案？
#
# (A) `'r'`
# (B) `'w'`
# (C) `'a'`
# (D) `'r+'`
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 14 題（1 分）
#
# 使用 `'w'` 模式開啟檔案時，若檔案不存在會發生什麼？
#
# (A) 拋出 `FileNotFoundError`
# (B) 自動建立新檔案
# (C) 返回 `None`
# (D) 拋出 `PermissionError`
#
# **你的答案**：

# %% [markdown]
# ---
#
# ### 第 15 題（1 分）
#
# 以下哪個最適合用於讀取**大型文字檔案**（數 GB）？
#
# (A) `content = f.read()`
# (B) `lines = f.readlines()`
# (C) `for line in f:`
# (D) `content = f.read().split('\n')`
#
# **你的答案**：

# %% [markdown]
# ---
#
# ## Part II: 程式碼輸出題（10 分）
#
# 請預測以下程式碼的輸出。
#
# ---

# %% [markdown]
# ### 第 16 題（2 分）
#
# 假設 `data.txt` 檔案內容為：
# ```
# apple
# banana
# cherry
# ```
#
# 以下程式碼的輸出是什麼？
#
# ```python
# with open('data.txt', 'r') as f:
#     lines = f.readlines()
#     print(len(lines))
#     print(lines[1])
# ```
#
# **你的答案**：
# ```
#
# ```

# %% [markdown]
# ---
#
# ### 第 17 題（2 分）
#
# 以下程式碼執行後，`output.txt` 的內容是什麼？
#
# ```python
# with open('output.txt', 'w') as f:
#     f.write('Line 1\n')
#
# with open('output.txt', 'a') as f:
#     f.write('Line 2\n')
# ```
#
# **你的答案**：
# ```
#
# ```

# %% [markdown]
# ---
#
# ### 第 18 題（2 分）
#
# 以下程式碼的輸出是什麼？
#
# ```python
# with open('test.txt', 'w') as f:
#     f.write('Hello')
#     f.write('World')
#
# with open('test.txt', 'r') as f:
#     print(f.read())
# ```
#
# **你的答案**：
# ```
#
# ```

# %% [markdown]
# ---
#
# ### 第 19 題（2 分）
#
# 假設 `numbers.txt` 內容為：
# ```
# 1
# 2
# 3
# ```
#
# 以下程式碼的輸出是什麼？
#
# ```python
# total = 0
# with open('numbers.txt', 'r') as f:
#     for line in f:
#         total += int(line.strip())
# print(total)
# ```
#
# **你的答案**：
# ```
#
# ```

# %% [markdown]
# ---
#
# ### 第 20 題（2 分）
#
# 以下程式碼會發生什麼？
#
# ```python
# try:
#     with open('nonexistent.txt', 'r') as f:
#         content = f.read()
# except FileNotFoundError:
#     print('檔案不存在')
# except PermissionError:
#     print('權限不足')
# ```
#
# **你的答案**：
# ```
#
# ```

# %% [markdown]
# ---
#
# ## Part III: 程式碼填空題（15 分）
#
# 請完成以下程式碼。
#
# ---

# %% [markdown]
# ### 第 21 題（3 分）
#
# 完成以下程式碼，使其能夠讀取 `input.txt` 並將內容寫入 `output.txt`（檔案複製）。
#
# ```python
# with open('input.txt', ____) as infile:
#     content = infile.____
#
# with open('output.txt', ____) as outfile:
#     outfile.____(content)
# ```
#
# **你的答案**：

# %%
# 在此填寫答案

# %% [markdown]
# ---
#
# ### 第 22 題（3 分）
#
# 完成以下程式碼，使其能夠統計 `data.txt` 中非空白行的數量。
#
# ```python
# count = 0
# with open('data.txt', 'r', encoding='utf-8') as f:
#     for line in f:
#         if line.____:  # 如果去除空白後不是空字串
#             count ____ 1
# print(f"非空白行數：{count}")
# ```
#
# **你的答案**：

# %%
# 在此填寫答案

# %% [markdown]
# ---
#
# ### 第 23 題（3 分）
#
# 完成以下程式碼，使其能夠將列表內容寫入檔案，每個元素一行。
#
# ```python
# fruits = ['apple', 'banana', 'cherry']
#
# with open('fruits.txt', ____) as f:
#     for fruit in fruits:
#         f.write(____ + '\n')  # 加上換行符號
# ```
#
# **你的答案**：

# %%
# 在此填寫答案

# %% [markdown]
# ---
#
# ### 第 24 題（3 分）
#
# 完成以下程式碼，安全地讀取檔案，若檔案不存在則建立並寫入預設內容。
#
# ```python
# filename = 'config.txt'
# default_content = 'debug=False'
#
# ____:
#     with open(filename, 'r') as f:
#         content = f.read()
#         print(content)
# except ____:
#     with open(filename, 'w') as f:
#         f.write(default_content)
#     print('已建立預設設定檔')
# ```
#
# **你的答案**：

# %%
# 在此填寫答案

# %% [markdown]
# ---
#
# ### 第 25 題（3 分）
#
# 完成以下函式，實作檔案反轉功能（最後一行變第一行）。
#
# ```python
# def reverse_file(input_file, output_file):
#     with open(input_file, ____) as f:
#         lines = f.____
#
#     with open(output_file, ____) as f:
#         f.writelines(____(lines))  # 反轉列表
#
# # 測試
# reverse_file('original.txt', 'reversed.txt')
# ```
#
# **你的答案**：

# %%
# 在此填寫答案

# %% [markdown]
# ---
#
# ## 解答與評分標準
#
# ### Part I 選擇題解答（15 分）
#
# 1. **(B)** - `'w'` 模式會覆蓋現有檔案
# 2. **(B)** - with 語句自動關閉檔案
# 3. **(C)** - `readlines()` 返回列表
# 4. **(C)** - `'a'` 模式用於附加
# 5. **(B)** - `HelloWorld`（write 不自動加換行）
# 6. **(C)** - 系統預設編碼
# 7. **(D)** - B 和 C 都不會自動加換行
# 8. **(C)** - 拋出 `FileNotFoundError`
# 9. **(C)** - ASCII 不支援中文
# 10. **(C)** - 檔案指標在結尾
# 11. **(C)** - `for line in f:` 最節省記憶體
# 12. **(B)** - 列表或可迭代物件
# 13. **(D)** - `'r+'` 可同時讀寫
# 14. **(B)** - 自動建立新檔案
# 15. **(C)** - `for line in f:` 適合大檔案
#
# ### Part II 程式碼輸出題解答（10 分）
#
# 16. **輸出**：
# ```
# 3
# banana
#
# ```
# （3 行，第二行是 `banana\n`）
#
# 17. **檔案內容**：
# ```
# Line 1
# Line 2
# ```
#
# 18. **輸出**：
# ```
# HelloWorld
# ```
#
# 19. **輸出**：
# ```
# 6
# ```
# （1+2+3=6）
#
# 20. **輸出**：
# ```
# 檔案不存在
# ```
#
# ### Part III 程式碼填空題解答（15 分）
#
# 21. **答案**：
# ```python
# with open('input.txt', 'r') as infile:
#     content = infile.read()
#
# with open('output.txt', 'w') as outfile:
#     outfile.write(content)
# ```
#
# 22. **答案**：
# ```python
# if line.strip():  # 或 line.strip() != ''
#     count += 1
# ```
#
# 23. **答案**：
# ```python
# with open('fruits.txt', 'w') as f:
#     for fruit in fruits:
#         f.write(fruit + '\n')
# ```
#
# 24. **答案**：
# ```python
# try:
#     ...
# except FileNotFoundError:
#     ...
# ```
#
# 25. **答案**：
# ```python
# def reverse_file(input_file, output_file):
#     with open(input_file, 'r') as f:
#         lines = f.readlines()
#
#     with open(output_file, 'w') as f:
#         f.writelines(reversed(lines))  # 或 lines[::-1]
# ```
#
# ---
#
# ## 評分標準
#
# | 分數範圍 | 等級 | 建議 |
# |---------|------|------|
# | 36-40 分 | 優秀 | 已充分掌握檔案 I/O，可進階學習 JSON/CSV |
# | 30-35 分 | 良好 | 基本概念良好，建議複習編碼與異常處理 |
# | 24-29 分 | 及格 | 需加強練習，重點複習 with 語句和讀寫方法 |
# | 0-23 分  | 不及格 | 建議重新學習本章，完成所有練習題 |
#
# ---
#
# ## 學習檢核清單
#
# 完成測驗後，檢視你是否掌握以下能力：
#
# ### ✅ 基礎能力
# - [ ] 使用不同模式開啟檔案（r, w, a）
# - [ ] 使用 with 語句管理檔案資源
# - [ ] 使用 read(), readline(), readlines() 讀取檔案
# - [ ] 使用 write(), writelines() 寫入檔案
#
# ### ✅ 進階能力
# - [ ] 正確處理檔案編碼（UTF-8, Big5）
# - [ ] 使用 try-except 處理檔案異常
# - [ ] 逐行迭代大型檔案
# - [ ] 處理換行符號和空白字元
#
# ### ✅ 實戰能力
# - [ ] 複製、合併、分割檔案
# - [ ] 統計和分析文字資料
# - [ ] 實作簡易文字處理工具
# - [ ] 處理實際檔案操作需求
#
# ---
#
# ## 下一步
#
# 根據你的測驗結果：
#
# **如果得分 ≥ 30 分**：
# 1. 複習錯誤的題目
# 2. 進入 Ch24: JSON 與資料序列化
# 3. 準備 Milestone 7 專案
#
# **如果得分 < 30 分**：
# 1. 重新閱讀 01-lecture.ipynb
# 2. 完成所有 03-practice.ipynb 練習
# 3. 完成 04-exercises.ipynb 習題
# 4. 一週後重新測驗
