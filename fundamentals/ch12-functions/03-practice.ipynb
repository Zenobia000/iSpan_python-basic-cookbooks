# %% [markdown]
# # Chapter 12: 函式設計基礎 | Function Fundamentals
#
# ## 🛠️ 課堂練習 | In-Class Practice
#
# 本檔案包含 12 個課堂練習題,用於即時檢驗理解程度。
#
# **使用方式**:
# 1. 閱讀每題的問題描述
# 2. 在提供的 code cell 中撰寫程式碼
# 3. 執行並檢查結果
# 4. 參考提示(如果卡住)
#
# **預計完成時間**:40 分鐘
#
# ---

# %% [markdown]
# ## 基礎題(5 題)
#
# ### 練習 1:計算圓面積 ⭐
#
# **要求**:
# 設計一個函式 `calculate_circle_area(radius)`,計算並回傳圓的面積。
#
# **公式**:面積 = π × 半徑²(使用 3.14159 作為 π)
#
# **測試**:
# - `calculate_circle_area(5)` → 應回傳 78.53975
# - `calculate_circle_area(10)` → 應回傳 314.159
#
# **提示**:使用 `**` 運算子計算平方

# %%
# 在此撰寫程式碼
def calculate_circle_area(radius):
    """
    計算圓面積
    
    參數:
        radius: 圓的半徑
    
    回傳:
        圓的面積
    """
    pass  # 請替換為你的程式碼

# 測試
print(f"半徑 5 的圓面積: {calculate_circle_area(5)}")
print(f"半徑 10 的圓面積: {calculate_circle_area(10)}")

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# pi = 3.14159
# area = pi * radius ** 2
# return area
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 2:判斷奇偶數 ⭐
#
# **要求**:
# 設計一個函式 `is_even(number)`,判斷一個數字是否為偶數。
#
# **回傳值**:
# - 偶數回傳 `True`
# - 奇數回傳 `False`
#
# **測試**:
# - `is_even(4)` → `True`
# - `is_even(7)` → `False`
#
# **提示**:使用 `%` 運算子檢查餘數

# %%
# 在此撰寫程式碼
def is_even(number):
    """
    判斷數字是否為偶數
    
    參數:
        number: 待判斷的整數
    
    回傳:
        bool: True 表示偶數,False 表示奇數
    """
    pass  # 請替換為你的程式碼

# 測試
print(f"4 是偶數: {is_even(4)}")
print(f"7 是偶數: {is_even(7)}")
print(f"0 是偶數: {is_even(0)}")

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# return number % 2 == 0
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 3:字串反轉 ⭐
#
# **要求**:
# 設計一個函式 `reverse_string(text)`,將字串反轉。
#
# **測試**:
# - `reverse_string("hello")` → `"olleh"`
# - `reverse_string("Python")` → `"nohtyP"`
#
# **提示**:使用切片 `[::-1]`

# %%
# 在此撰寫程式碼
def reverse_string(text):
    """
    反轉字串
    
    參數:
        text: 原始字串
    
    回傳:
        反轉後的字串
    """
    pass  # 請替換為你的程式碼

# 測試
print(reverse_string("hello"))
print(reverse_string("Python"))
print(reverse_string("12345"))

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# return text[::-1]
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 4:找出最大值 ⭐
#
# **要求**:
# 設計一個函式 `find_max(a, b, c)`,接收三個數字,回傳最大值。
#
# **測試**:
# - `find_max(10, 5, 8)` → `10`
# - `find_max(3, 9, 7)` → `9`
#
# **提示**:可以使用內建函式 `max()`,或使用 `if-elif-else`

# %%
# 在此撰寫程式碼
def find_max(a, b, c):
    """
    找出三個數字中的最大值
    
    參數:
        a, b, c: 三個數字
    
    回傳:
        最大值
    """
    pass  # 請替換為你的程式碼

# 測試
print(f"max(10, 5, 8) = {find_max(10, 5, 8)}")
print(f"max(3, 9, 7) = {find_max(3, 9, 7)}")
print(f"max(-1, -5, -3) = {find_max(-1, -5, -3)}")

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# 方法 1:使用內建函式
# ```python
# return max(a, b, c)
# ```
#
# 方法 2:使用條件判斷
# ```python
# if a >= b and a >= c:
#     return a
# elif b >= c:
#     return b
# else:
#     return c
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 5:攝氏華氏轉換 ⭐
#
# **要求**:
# 設計一個函式 `celsius_to_fahrenheit(celsius)`,將攝氏溫度轉換為華氏溫度。
#
# **公式**:華氏 = 攝氏 × 9/5 + 32
#
# **測試**:
# - `celsius_to_fahrenheit(0)` → `32.0`
# - `celsius_to_fahrenheit(25)` → `77.0`
# - `celsius_to_fahrenheit(100)` → `212.0`

# %%
# 在此撰寫程式碼
def celsius_to_fahrenheit(celsius):
    """
    攝氏轉華氏
    
    參數:
        celsius: 攝氏溫度
    
    回傳:
        華氏溫度
    """
    pass  # 請替換為你的程式碼

# 測試
print(f"0°C = {celsius_to_fahrenheit(0)}°F")
print(f"25°C = {celsius_to_fahrenheit(25)}°F")
print(f"100°C = {celsius_to_fahrenheit(100)}°F")

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# return celsius * 9/5 + 32
# ```
# </details>
#
# ---

# %% [markdown]
# ## 進階題(5 題)
#
# ### 練習 6:計算折扣價格 ⭐⭐
#
# **要求**:
# 設計一個函式 `calculate_discount(price, discount=0.9)`,計算折扣後價格。
#
# **參數**:
# - `price`:原價
# - `discount`:折扣(預設 0.9,即九折)
#
# **測試**:
# - `calculate_discount(100)` → `90.0`(使用預設九折)
# - `calculate_discount(100, 0.8)` → `80.0`(八折)
# - `calculate_discount(100, discount=0.7)` → `70.0`(七折)

# %%
# 在此撰寫程式碼
def calculate_discount(price, discount=0.9):
    """
    計算折扣後價格
    
    參數:
        price: 原價
        discount: 折扣(預設 0.9)
    
    回傳:
        折扣後價格
    """
    pass  # 請替換為你的程式碼

# 測試
print(f"原價 100,預設折扣: {calculate_discount(100)}")
print(f"原價 100,八折: {calculate_discount(100, 0.8)}")
print(f"原價 100,七折: {calculate_discount(100, discount=0.7)}")

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# return price * discount
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 7:生成問候語 ⭐⭐
#
# **要求**:
# 設計一個函式 `greet(name, time="早安")`,生成問候語。
#
# **參數**:
# - `name`:姓名(必要)
# - `time`:時段(預設 "早安")
#
# **測試**:
# - `greet("小明")` → `"早安,小明!"`
# - `greet("小華", "午安")` → `"午安,小華!"`
# - `greet("小美", time="晚安")` → `"晚安,小美!"`

# %%
# 在此撰寫程式碼
def greet(name, time="早安"):
    """
    生成問候語
    
    參數:
        name: 姓名
        time: 時段(預設 "早安")
    
    回傳:
        問候語字串
    """
    pass  # 請替換為你的程式碼

# 測試
print(greet("小明"))
print(greet("小華", "午安"))
print(greet("小美", time="晚安"))

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# return f"{time},{name}!"
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 8:計算 BMI 並分類 ⭐⭐
#
# **要求**:
# 設計一個函式 `calculate_bmi(weight, height)`,計算 BMI 並回傳分類。
#
# **公式**:BMI = 體重(kg) / 身高(m)²
#
# **分類標準**:
# - BMI < 18.5:"過輕"
# - 18.5 ≤ BMI < 24:"正常"
# - 24 ≤ BMI < 27:"過重"
# - BMI ≥ 27:"肥胖"
#
# **回傳**:回傳 tuple `(BMI值, 分類)`
#
# **測試**:
# - `calculate_bmi(70, 1.75)` → `(22.86, "正常")`

# %%
# 在此撰寫程式碼
def calculate_bmi(weight, height):
    """
    計算 BMI 並分類
    
    參數:
        weight: 體重(公斤)
        height: 身高(公尺)
    
    回傳:
        tuple: (BMI值, 分類)
    """
    pass  # 請替換為你的程式碼

# 測試
bmi, category = calculate_bmi(70, 1.75)
print(f"BMI: {bmi:.2f}, 分類: {category}")

bmi, category = calculate_bmi(50, 1.65)
print(f"BMI: {bmi:.2f}, 分類: {category}")

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# bmi = weight / (height ** 2)
# if bmi < 18.5:
#     category = "過輕"
# elif bmi < 24:
#     category = "正常"
# elif bmi < 27:
#     category = "過重"
# else:
#     category = "肥胖"
# return round(bmi, 2), category
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 9:列表去重 ⭐⭐
#
# **要求**:
# 設計一個函式 `remove_duplicates(items)`,移除列表中的重複元素。
#
# **測試**:
# - `remove_duplicates([1, 2, 2, 3, 3, 3, 4])` → `[1, 2, 3, 4]`
# - `remove_duplicates(["a", "b", "a", "c"])` → `["a", "b", "c"]`
#
# **提示**:可以使用 `set()` 轉換後再轉回 `list()`,或使用迴圈判斷

# %%
# 在此撰寫程式碼
def remove_duplicates(items):
    """
    移除列表中的重複元素
    
    參數:
        items: 原始列表
    
    回傳:
        去重後的列表
    """
    pass  # 請替換為你的程式碼

# 測試
print(remove_duplicates([1, 2, 2, 3, 3, 3, 4]))
print(remove_duplicates(["a", "b", "a", "c"]))
print(remove_duplicates([5, 5, 5, 5]))

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# 方法 1:使用 set
# ```python
# return list(set(items))
# ```
#
# 方法 2:使用迴圈(保持順序)
# ```python
# result = []
# for item in items:
#     if item not in result:
#         result.append(item)
# return result
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 10:字典合併 ⭐⭐
#
# **要求**:
# 設計一個函式 `merge_dicts(dict1, dict2)`,合併兩個字典。
#
# **規則**:如果有相同的鍵,使用 `dict2` 的值
#
# **測試**:
# ```python
# d1 = {"a": 1, "b": 2}
# d2 = {"b": 3, "c": 4}
# merge_dicts(d1, d2)  # → {"a": 1, "b": 3, "c": 4}
# ```
#
# **提示**:可以使用 `{**dict1, **dict2}` 或 `dict1.copy()` + `update()`

# %%
# 在此撰寫程式碼
def merge_dicts(dict1, dict2):
    """
    合併兩個字典
    
    參數:
        dict1: 第一個字典
        dict2: 第二個字典
    
    回傳:
        合併後的字典
    """
    pass  # 請替換為你的程式碼

# 測試
d1 = {"a": 1, "b": 2}
d2 = {"b": 3, "c": 4}
print(merge_dicts(d1, d2))

d3 = {"name": "Alice", "age": 25}
d4 = {"age": 26, "city": "Taipei"}
print(merge_dicts(d3, d4))

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# 方法 1:使用解包
# ```python
# return {**dict1, **dict2}
# ```
#
# 方法 2:使用 copy 和 update
# ```python
# result = dict1.copy()
# result.update(dict2)
# return result
# ```
# </details>
#
# ---

# %% [markdown]
# ## 挑戰題(2 題)
#
# ### 練習 11:成績管理函式 ⭐⭐⭐
#
# **要求**:
# 設計一個函式 `analyze_scores(scores)`,分析成績列表。
#
# **回傳**:字典包含以下資訊:
# - `average`:平均分數
# - `pass_rate`:及格率(≥60 分)
# - `grade_distribution`:等第分佈(A/B/C/D/F 各多少人)
#
# **等第標準**:
# - A: ≥90, B: ≥80, C: ≥70, D: ≥60, F: <60
#
# **測試**:
# ```python
# scores = [85, 92, 78, 95, 62, 88, 73, 55]
# analyze_scores(scores)
# # 應回傳類似:
# # {
# #   'average': 78.5,
# #   'pass_rate': 0.875,  # 7/8
# #   'grade_distribution': {'A': 2, 'B': 3, 'C': 1, 'D': 1, 'F': 1}
# # }
# ```

# %%
# 在此撰寫程式碼
def analyze_scores(scores):
    """
    分析成績統計
    
    參數:
        scores: 成績列表
    
    回傳:
        dict: 包含平均、及格率、等第分佈
    """
    pass  # 請替換為你的程式碼

# 測試
scores = [85, 92, 78, 95, 62, 88, 73, 55]
result = analyze_scores(scores)
print("成績分析:")
print(f"平均: {result['average']:.2f}")
print(f"及格率: {result['pass_rate']:.1%}")
print(f"等第分佈: {result['grade_distribution']}")

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# average = sum(scores) / len(scores)
# pass_count = sum(1 for s in scores if s >= 60)
# pass_rate = pass_count / len(scores)
#
# grades = {'A': 0, 'B': 0, 'C': 0, 'D': 0, 'F': 0}
# for score in scores:
#     if score >= 90:
#         grades['A'] += 1
#     elif score >= 80:
#         grades['B'] += 1
#     elif score >= 70:
#         grades['C'] += 1
#     elif score >= 60:
#         grades['D'] += 1
#     else:
#         grades['F'] += 1
#
# return {
#     'average': average,
#     'pass_rate': pass_rate,
#     'grade_distribution': grades
# }
# ```
# </details>
#
# ---

# %% [markdown]
# ### 練習 12:購物車計算 ⭐⭐⭐
#
# **要求**:
# 設計一個函式 `calculate_cart(items, coupon=None)`,計算購物車總價。
#
# **參數**:
# - `items`:商品列表,每個商品是 `{"name": ..., "price": ..., "quantity": ...}`
# - `coupon`:優惠碼(可選)
#   - `"SAVE10"`:打九折
#   - `"SAVE20"`:打八折
#   - `None`:無折扣
#
# **回傳**:字典包含:
# - `subtotal`:小計
# - `discount`:折扣金額
# - `total`:總計
#
# **測試**:
# ```python
# cart = [
#     {"name": "蘋果", "price": 30, "quantity": 2},
#     {"name": "牛奶", "price": 50, "quantity": 1}
# ]
# calculate_cart(cart, "SAVE10")
# # → {'subtotal': 110, 'discount': 11.0, 'total': 99.0}
# ```

# %%
# 在此撰寫程式碼
def calculate_cart(items, coupon=None):
    """
    計算購物車總價
    
    參數:
        items: 商品列表
        coupon: 優惠碼(可選)
    
    回傳:
        dict: 小計、折扣、總計
    """
    pass  # 請替換為你的程式碼

# 測試
cart = [
    {"name": "蘋果", "price": 30, "quantity": 2},
    {"name": "牛奶", "price": 50, "quantity": 1}
]

print("無折扣:", calculate_cart(cart))
print("SAVE10:", calculate_cart(cart, "SAVE10"))
print("SAVE20:", calculate_cart(cart, "SAVE20"))

# %% [markdown]
# <details>
# <summary>💡 提示(點擊展開)</summary>
#
# ```python
# subtotal = sum(item['price'] * item['quantity'] for item in items)
#
# discount_rate = 0
# if coupon == "SAVE10":
#     discount_rate = 0.1
# elif coupon == "SAVE20":
#     discount_rate = 0.2
#
# discount = subtotal * discount_rate
# total = subtotal - discount
#
# return {
#     'subtotal': subtotal,
#     'discount': discount,
#     'total': total
# }
# ```
# </details>
#
# ---

# %% [markdown]
# ## 🎯 練習總結
#
# ### 涵蓋的知識點
#
# | 練習 | 主題 | 難度 | 重點技能 |
# |:----:|:-----|:----:|:---------|
# | 1 | 基本函式定義 | ⭐ | 參數、回傳值 |
# | 2 | Bool 回傳 | ⭐ | 條件判斷 |
# | 3 | 字串處理 | ⭐ | 切片操作 |
# | 4 | 多參數函式 | ⭐ | max 函式 |
# | 5 | 數學計算 | ⭐ | 公式應用 |
# | 6 | 預設參數 | ⭐⭐ | 參數設計 |
# | 7 | 字串格式化 | ⭐⭐ | f-string |
# | 8 | 多重回傳值 | ⭐⭐ | tuple unpacking |
# | 9 | 列表處理 | ⭐⭐ | 去重技巧 |
# | 10 | 字典操作 | ⭐⭐ | 合併字典 |
# | 11 | 綜合分析 | ⭐⭐⭐ | 統計計算 |
# | 12 | 實務應用 | ⭐⭐⭐ | 購物車邏輯 |
#
# ### 檢核清單
#
# 完成練習後,確認你能夠:
# - [ ] 定義函式並正確使用參數
# - [ ] 使用 return 回傳值
# - [ ] 設計具有預設參數的函式
# - [ ] 回傳多個值(tuple)
# - [ ] 撰寫清晰的 docstring
# - [ ] 處理列表和字典
# - [ ] 實作實務邏輯
#
# ---
#
# ## 📚 下一步
#
# 1. 確保所有練習都能正確執行
# 2. 對照 `05-solutions.ipynb` 檢查答案
# 3. 繼續完成 `04-exercises.ipynb`(課後習題)
