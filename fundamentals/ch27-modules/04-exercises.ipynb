# %% [markdown]
# # 自訂模組與套件 | Custom Modules and Packages## ✍️ 課後習題 | Homework Exercises---## 💡 習題說明本檔案包含 **18 個課後習題**，分為三個難度等級：- 🟢 **基礎題** (1-6)：6 題- 🟡 **中級題** (7-14)：8 題- 🔴 **挑戰題** (15-18)：4 題**預估時間**：90-120 分鐘**評分標準**：- 程式碼正確性：60%- 程式碼品質（註解、命名）：20%- 模組設計（組織、重用性）：20%---

# %% [markdown]
# ## 🟢 基礎題---## 習題 1：溫度轉換模組建立 `temperature.py` 模組，提供溫度單位轉換：- 攝氏 ↔ 華氏- 攝氏 ↔ 克氏 (Kelvin)- 華氏 ↔ 克氏要求：1. 6 個轉換函式（每個方向一個函式）2. 完整的 docstring3. `if __name__ == "__main__"` 測試程式碼4. 在主程式中測試所有函式**提示**：- 攝氏轉華氏：F = C × 9/5 + 32- 攝氏轉克氏：K = C + 273.15

# %%
# 習題 1: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 2：日期工具模組建立 `date_utils.py` 模組，提供日期相關功能：1. `get_current_date()`: 取得當前日期字串（格式：YYYY-MM-DD）2. `get_current_time()`: 取得當前時間字串（格式：HH:MM:SS）3. `days_between(date1, date2)`: 計算兩日期間隔天數4. `is_weekend(date)`: 判斷是否為週末要求：- 使用 `datetime` 模組- 日期格式使用 ISO 8601- 處理錯誤輸入

# %%
# 習題 2: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 3：字串處理模組建立 `text_processor.py` 模組，提供字串處理功能：1. `count_characters(text)`: 計算字元數（不含空格）2. `count_words(text)`: 計算字數3. `count_sentences(text)`: 計算句子數（以 .!? 結尾）4. `most_common_word(text)`: 找出最常出現的字（忽略大小寫）要求：- 處理標點符號- 忽略大小寫- 返回有意義的統計資料

# %%
# 習題 3: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 4：數學函式模組建立 `math_functions.py` 模組，提供數學計算：1. `is_even(n)`: 判斷偶數2. `is_odd(n)`: 判斷奇數3. `sum_of_digits(n)`: 計算數字各位數總和4. `reverse_number(n)`: 反轉數字（123 → 321）5. `is_armstrong(n)`: 判斷阿姆斯壯數（153 = 1³ + 5³ + 3³）要求：- 處理負數情況- 提供完整測試

# %%
# 習題 4: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 5：列表工具模組建立 `list_tools.py` 模組，提供列表操作：1. `find_max(lst)`: 找出最大值2. `find_min(lst)`: 找出最小值3. `find_second_largest(lst)`: 找出第二大的數4. `remove_duplicates(lst)`: 移除重複（保持順序）5. `merge_sorted_lists(lst1, lst2)`: 合併兩個已排序列表要求：- 處理空列表- 處理列表長度不足的情況- 測試各種情境

# %%
# 習題 5: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 6：檔案統計模組建立 `file_stats.py` 模組，分析文字檔案：1. `count_lines(filename)`: 計算總行數2. `count_empty_lines(filename)`: 計算空行數3. `count_code_lines(filename)`: 計算非空行數4. `longest_line(filename)`: 找出最長的行5. `file_size(filename)`: 取得檔案大小（bytes）要求：- 處理檔案不存在的情況- 支援 UTF-8 編碼- 返回有意義的統計資料

# %%
# 習題 6: 在此撰寫你的程式碼

# %% [markdown]
# ---## 🟡 中級題---## 習題 7：建立 geometry 套件建立幾何計算套件，結構如下：```geometry/├── __init__.py├── circle.py├── rectangle.py└── triangle.py```每個模組提供相應圖形的：- 面積計算- 周長計算- 其他相關計算（如對角線長度）要求：1. 在 `__init__.py` 中匯入所有類別2. 使用類別封裝（Circle, Rectangle, Triangle）3. 提供 `__str__()` 方法顯示資訊4. 設定 `__version__` 和 `__all__`**測試**：```pythonfrom geometry import Circle, Rectangle, Trianglec = Circle(5)print(c)  # Circle(radius=5, area=78.54, perimeter=31.42)print(c.area())```

# %%
# 習題 7: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 8：學生管理套件建立學生管理系統套件：```student_system/├── __init__.py├── student.py       # Student 類別├── course.py        # Course 類別└── manager.py       # StudentManager 類別```**功能需求**：- `Student`: 學號、姓名、成績字典- `Course`: 課程名稱、學分、成績- `StudentManager`: 新增、刪除、查詢、統計要求：1. Student 可以新增課程成績2. Manager 可以計算 GPA3. Manager 可以產生成績報表4. 提供範例程式 `demo.py`

# %%
# 習題 8: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 9：使用 importlib 動態載入外掛建立一個外掛系統，可以動態載入外掛模組：**主程式** (`plugin_manager.py`):- 搜尋 `plugins/` 資料夾中的所有 .py 檔案- 動態載入每個外掛- 呼叫外掛的 `run()` 函式**外掛範例** (`plugins/hello.py`):```pythondef run():    print("Hello Plugin!")```要求：1. 使用 `importlib.import_module()`2. 檢查外掛是否有 `run()` 函式3. 處理載入失敗的情況4. 顯示已載入的外掛列表

# %%
# 習題 9: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 10：資料序列化套件建立資料序列化工具套件：```serializers/├── __init__.py├── json_serializer.py├── csv_serializer.py└── pickle_serializer.py```每個序列化器提供：- `save(data, filename)`: 儲存資料- `load(filename)`: 載入資料要求：1. 統一的介面（可使用抽象基底類別）2. 處理不同資料型態3. 錯誤處理4. 測試程式

# %%
# 習題 10: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 11：日誌記錄模組建立進階的日誌記錄模組 `logger.py`：功能：1. 支援多個日誌等級（DEBUG, INFO, WARNING, ERROR）2. 同時輸出到檔案和控制台3. 自動加入時間戳記4. 支援日誌檔案輪替（按日期）使用範例：```pythonfrom logger import Loggerlog = Logger('myapp')log.info("應用程式啟動")log.error("發生錯誤")```要求：- 使用單例模式（Singleton）- 檔案名稱格式：`app_YYYY-MM-DD.log`- 可設定日誌等級

# %%
# 習題 11: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 12：配置管理套件建立應用程式配置管理套件：```config/├── __init__.py├── loader.py      # 載入配置檔├── validator.py   # 驗證配置└── defaults.py    # 預設配置```功能：1. 支援多種格式（JSON, YAML-style）2. 配置驗證（必填欄位、型態檢查）3. 預設值處理4. 環境變數覆蓋使用範例：```pythonfrom config import Configcfg = Config.from_file('app.json')db_host = cfg.get('database.host', default='localhost')```要求：- 支援巢狀配置存取（點號語法）- 型態安全- 完整錯誤訊息

# %%
# 習題 12: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 13：相對匯入與絕對匯入實驗建立以下套件結構並實驗匯入方式：```myproject/├── __init__.py├── main.py├── core/│   ├── __init__.py│   ├── engine.py│   └── utils.py└── plugins/    ├── __init__.py    └── addon.py```要求：1. 在 `engine.py` 中使用相對匯入載入 `utils`2. 在 `addon.py` 中使用相對匯入載入 `core.engine`3. 在 `main.py` 中使用絕對匯入載入所有模組4. 比較兩種匯入方式的優缺點（以註解說明）5. 測試從套件外部和內部執行的差異

# %%
# 習題 13: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 14：模組重新載入實驗建立一個實驗，展示模組重新載入的機制：步驟：1. 建立 `counter.py` 模組，包含一個計數器變數和函式2. 在主程式中匯入並使用3. 修改 `counter.py` 的內容（增加新函式）4. 使用 `importlib.reload()` 重新載入5. 驗證新函式可以使用探討：- 模組層級變數在重新載入後的狀態- 已經建立的物件是否受影響- 什麼情況下需要重新載入模組要求：- 完整的實驗步驟- 觀察結果記錄（以註解或 print 呈現）- 結論與最佳實務建議

# %%
# 習題 14: 在此撰寫你的程式碼

# %% [markdown]
# ---## 🔴 挑戰題---## 習題 15：解決複雜的循環匯入以下是一個複雜的循環匯入情境，請修復：**user.py**:```pythonfrom order import Orderfrom payment import Paymentclass User:    def create_order(self, items):        order = Order(self, items)        return order    def make_payment(self, amount):        payment = Payment(self, amount)        return payment```**order.py**:```pythonfrom user import Userfrom payment import Paymentclass Order:    def __init__(self, user, items):        self.user = user        self.items = items    def create_payment(self):        return Payment(self.user, self.calculate_total())```**payment.py**:```pythonfrom user import Userfrom order import Orderclass Payment:    def __init__(self, user, amount):        self.user = user        self.amount = amount```要求：1. 辨識所有循環依賴2. 提供至少兩種重構方案3. 實作最佳解決方案4. 說明每種方案的優缺點

# %%
# 習題 15: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 16：建立可安裝的命令列工具套件建立一個完整的命令列工具套件 `mytool`：**專案結構**：```mytool-project/├── mytool/│   ├── __init__.py│   ├── cli.py         # 命令列介面│   ├── commands/      # 命令子套件│   │   ├── __init__.py│   │   ├── hello.py│   │   └── calc.py│   └── utils.py       # 工具函式├── tests/│   └── test_cli.py├── setup.py├── README.md└── requirements.txt```**功能需求**：1. 支援多個子命令（hello, calc）2. 參數解析（使用 argparse）3. 可以用 `pip install -e .` 安裝4. 安裝後可在終端執行 `mytool hello`**setup.py 要求**：- 定義 entry_points 讓命令可在終端執行- 包含完整的元資料- 列出依賴套件要求：- 完整的專案結構- 可執行的命令- 完整的文件- 測試腳本

# %%
# 習題 16: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 17：建立模組依賴分析工具建立一個工具，分析 Python 專案的模組依賴關係：功能：1. 掃描專案資料夾中的所有 .py 檔案2. 解析每個檔案的 import 語句3. 建立依賴關係圖4. 偵測循環依賴5. 生成視覺化報告（文字格式）輸出範例：```=== 模組依賴分析 ===模組: main.py  匯入: utils, config模組: utils.py  匯入: helpers模組: config.py  匯入: 無❌ 偵測到循環依賴:  module_a.py → module_b.py → module_a.py```要求：- 使用 `ast` 模組解析原始碼- 支援相對匯入和絕對匯入- 使用圖演算法偵測循環- 生成清晰的報告

# %%
# 習題 17: 在此撰寫你的程式碼

# %% [markdown]
# ---## 習題 18：建立套件管理工具建立一個迷你套件管理工具 `pkgman`：功能：1. **安裝套件**：從 GitHub 或本地路徑複製到 `~/.mypkgs/`2. **列出套件**：顯示已安裝的套件3. **移除套件**：刪除已安裝的套件4. **載入套件**：動態載入已安裝的套件使用範例：```pythonfrom pkgman import PackageManagerpm = PackageManager()pm.install('myutils', source='./myutils')pm.list_packages()# 輸出: myutils v1.0.0module = pm.load('myutils')module.some_function()```要求：- 套件安裝到固定目錄- 套件需要有 `__version__` 屬性- 使用 `sys.path` 和 `importlib`- 處理套件衝突（同名套件）- 提供命令列介面進階：- 支援套件依賴- 版本管理- 套件搜尋功能

# %%
# 習題 18: 在此撰寫你的程式碼

# %% [markdown]
# ---## 🎯 習題完成檢查表**基礎題** (6 題)：- [ ] 習題 1: 溫度轉換模組- [ ] 習題 2: 日期工具模組- [ ] 習題 3: 字串處理模組- [ ] 習題 4: 數學函式模組- [ ] 習題 5: 列表工具模組- [ ] 習題 6: 檔案統計模組**中級題** (8 題)：- [ ] 習題 7: geometry 套件- [ ] 習題 8: 學生管理套件- [ ] 習題 9: 動態載入外掛- [ ] 習題 10: 資料序列化套件- [ ] 習題 11: 日誌記錄模組- [ ] 習題 12: 配置管理套件- [ ] 習題 13: 相對與絕對匯入- [ ] 習題 14: 模組重新載入實驗**挑戰題** (4 題)：- [ ] 習題 15: 複雜循環匯入- [ ] 習題 16: 命令列工具套件- [ ] 習題 17: 模組依賴分析工具- [ ] 習題 18: 套件管理工具---**完成後**：請查看 `05-solutions.ipynb` 對照答案，並思考：1. 我的解法與標準答案有何不同？2. 是否有更優雅的實作方式？3. 模組設計是否符合單一職責原則？**學習提醒**：模組化設計是軟體工程的基礎。良好的模組組織讓程式碼易於維護、測試和重用！
