# %% [markdown]
# # 自訂模組與套件 | Custom Modules and Packages## 📝 自我測驗 | Self-Assessment Quiz---## 💡 測驗說明本測驗包含 **20 題**，分為兩大類：- **選擇題** (1-10)：測試概念理解- **程式題** (11-20)：測試實作能力**時間**：20-30 分鐘**及格分數**：70 分（14 題以上正確）**評分標準**：- 選擇題：每題 5 分- 程式題：每題 5 分---

# %% [markdown]
# ## 第一部分：選擇題（每題 5 分，共 50 分）---### 題目 1下列關於模組的敘述，何者**正確**？A. 模組就是資料夾B. 每個 .py 檔案都是一個模組C. 模組必須包含 `__init__.py`D. 模組不能匯入其他模組<details><summary>點擊查看答案</summary><b>答案：B</b><br>解析：每個 .py 檔案都是一個模組。資料夾要成為套件才需要 __init__.py（Python 3.3+ 可省略）。</details>---### 題目 2以下哪個 `import` 語法是**錯誤**的？A. `import math`B. `from math import sqrt`C. `import math as m`D. `from math import *` （假設不考慮最佳實務）E. `import math.sqrt`<details><summary>點擊查看答案</summary><b>答案：E</b><br>解析：應該使用 `from math import sqrt` 或 `import math` 再用 `math.sqrt()`。不能用 `import math.sqrt`。</details>---### 題目 3`if __name__ == "__main__":` 的作用是什麼？A. 檢查檔案名稱是否為 main.pyB. 區分模組是被執行還是被匯入C. 檢查是否為主函式D. 讓模組無法被匯入<details><summary>點擊查看答案</summary><b>答案：B</b><br>解析：當模組直接執行時 __name__ == "__main__"，當被匯入時 __name__ 為模組名稱。</details>---### 題目 4關於套件（Package），下列敘述何者**錯誤**？A. 套件是包含 `__init__.py` 的資料夾B. 套件可以包含子套件C. `__init__.py` 可以是空檔案D. 套件名稱必須使用大寫開頭<details><summary>點擊查看答案</summary><b>答案：D</b><br>解析：Python 慣例建議套件名稱使用小寫字母（PEP 8）。</details>---### 題目 5相對匯入 `from .. import module` 中的 `..` 表示什麼？A. 當前資料夾B. 上層資料夾C. 根目錄D. 錯誤語法<details><summary>點擊查看答案</summary><b>答案：B</b><br>解析：`.` 表示當前套件，`..` 表示上層套件，類似檔案系統的相對路徑。</details>---### 題目 6Python 搜尋模組的順序是？A. sys.path → 當前目錄 → 標準庫B. 標準庫 → sys.path → 當前目錄C. 當前目錄 → sys.path → 標準庫D. 當前目錄 → 標準庫 → sys.path<details><summary>點擊查看答案</summary><b>答案：C</b><br>解析：Python 按 sys.path 順序搜尋，而 sys.path[0] 通常是當前目錄或腳本所在目錄。</details>---### 題目 7循環匯入（Circular Import）問題的最佳解決方案是？A. 使用 `import *`B. 重構程式碼，避免循環依賴C. 使用更多的 import 語句D. 刪除其中一個模組<details><summary>點擊查看答案</summary><b>答案：B</b><br>解析：最佳方案是重新設計模組結構，避免雙向依賴。延遲匯入只是權宜之計。</details>---### 題目 8`__all__` 變數的作用是？A. 列出模組的所有變數B. 控制 `from module import *` 的行為C. 列出模組的所有函式D. 標記私有變數<details><summary>點擊查看答案</summary><b>答案：B</b><br>解析：__all__ 定義了 `from module import *` 時會匯入哪些名稱。</details>---### 題目 9下列哪個模組名稱符合 PEP 8 規範？A. `MyModule.py`B. `my_module.py`C. `MY_MODULE.py`D. `my-module.py`<details><summary>點擊查看答案</summary><b>答案：B</b><br>解析：模組名稱應使用小寫字母加底線（snake_case），避免使用連字號。</details>---### 題目 10使用 `importlib.reload(module)` 的主要時機是？A. 第一次匯入模組時B. 模組內容被修改後需要重新載入C. 每次使用模組時D. 程式結束時<details><summary>點擊查看答案</summary><b>答案：B</b><br>解析：reload() 用於開發時，當模組內容修改後需要重新載入而不重啟 Python。</details>---

# %% [markdown]
# ## 第二部分：程式題（每題 5 分，共 50 分）---### 題目 11撰寫一個模組 `string_utils.py`，包含函式 `count_vowels(text)` 計算英文母音數量。**測試**：```pythonfrom string_utils import count_vowelsprint(count_vowels("Hello World"))  # 3```

# %%
# 題目 11: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 12建立模組 `list_utils.py`，提供 `flatten(nested_list)` 函式展平巢狀列表。**測試**：```pythonfrom list_utils import flattenprint(flatten([1, [2, 3], [4, [5, 6]]]))  # [1, 2, 3, 4, 5, 6]```

# %%
# 題目 12: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 13撰寫程式碼，動態匯入模組並呼叫其中的函式。**要求**：1. 使用 `importlib.import_module()`2. 使用 `getattr()` 取得函式3. 處理模組不存在的情況

# %%
# 題目 13: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 14建立套件 `mathtools`，包含 `__init__.py` 和 `calculator.py`，並在 `__init__.py` 中匯入 calculator 的函式。**結構**：```mathtools/├── __init__.py└── calculator.py```

# %%
# 題目 14: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 15撰寫程式碼，查看當前的 `sys.path` 並新增一個自訂路徑。

# %%
# 題目 15: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 16建立兩個模組 `module_a.py` 和 `module_b.py`，演示 `if __name__ == "__main__"` 的使用。

# %%
# 題目 16: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 17撰寫程式碼，檢查一個模組是否有特定屬性（使用 `hasattr()` 和 `getattr()`）。

# %%
# 題目 17: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 18建立一個模組，包含私有函式（以 `_` 開頭）和公開函式，並測試從外部匯入的行為。

# %%
# 題目 18: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 19撰寫程式碼，使用相對匯入在套件內部匯入模組。**套件結構**：```mypackage/├── __init__.py├── module_a.py└── module_b.py```要求：在 `module_a.py` 中使用相對匯入載入 `module_b`。

# %%
# 題目 19: 在此撰寫你的程式碼

# %% [markdown]
# ---### 題目 20建立一個簡單的外掛系統：1. 建立 `plugins/` 資料夾2. 撰寫一個外掛 `hello_plugin.py`（包含 `run()` 函式）3. 撰寫主程式動態載入並執行所有外掛

# %%
# 題目 20: 在此撰寫你的程式碼

# %% [markdown]
# ---## 📊 自我評分### 選擇題答案1. **B** - 每個 .py 檔案都是模組2. **E** - 不能用 `import math.sqrt`3. **B** - 區分執行與匯入4. **D** - 套件名稱應小寫5. **B** - `..` 表示上層6. **C** - 當前目錄 → sys.path → 標準庫7. **B** - 重構程式碼8. **B** - 控制 `import *` 行為9. **B** - `my_module.py`10. **B** - 模組修改後重新載入### 程式題評分標準每題 5 分，依據以下標準評分：- **5 分**：完全正確，程式碼清晰- **3-4 分**：基本正確，但有小錯誤或不夠優雅- **1-2 分**：思路正確，但實作有問題- **0 分**：錯誤或未作答---## 🎯 成績評估| 分數範圍 | 等級 | 建議 ||:---------|:-----|:-----|| 90-100 | 優秀 | 已完全掌握本章知識，可進入下一章 || 70-89 | 良好 | 基本掌握，建議複習錯誤的部分 || 60-69 | 及格 | 需要加強練習，重做習題 || < 60 | 不及格 | 建議重新學習本章內容 |---**學習提醒**：模組化設計是軟體工程的核心。請確保真正理解每個概念，而非死記硬背！**下一步**：- 複習錯誤的題目- 重做 `04-exercises.ipynb` 中相關習題- 進入 **Chapter 28: 套件管理與虛擬環境**
