# %% [markdown]
# # Chapter 2: 運算子與表達式 | Operators and Expressions
#
# ## 📝 自我測驗 | Self-Assessment Quiz
#
# 本測驗包含 **15 題選擇題** 和 **5 題程式題**，用於檢核學習成效。
#
# **測驗規則**：
# - 選擇題：每題 4 分，共 60 分
# - 程式題：每題 8 分，共 40 分
# - 總分：100 分
# - 及格標準：70 分
#
# **使用方式**：
# 1. 獨立完成，不查閱資料
# 2. 記錄答案
# 3. 對照答案計分
# 4. 檢討錯題
#
# **預計完成時間**：20 分鐘
#
# ---

# %% [markdown]
# ## Part I: 選擇題（60 分）
#
# ### 題組 A：算術運算子（1-5）
#
# #### 1. `10 + 5 * 2` 的結果是？
# A) 30
# B) 20
# C) 15
# D) 25
#
# **答案**：_____
#
# ---
#
# #### 2. `17 // 5` 的結果是？
# A) 3.4
# B) 3
# C) 4
# D) 2
#
# **答案**：_____
#
# ---
#
# #### 3. `17 % 5` 的結果是？
# A) 3
# B) 2
# C) 4
# D) 1
#
# **答案**：_____
#
# ---
#
# #### 4. `2 ** 3 ** 2` 的結果是？（注意：** 是右結合）
# A) 64
# B) 512
# C) 256
# D) 128
#
# **答案**：_____
#
# ---
#
# #### 5. 以下哪個表達式的結果是 int 型態？
# A) `10 / 2`
# B) `10 // 2`
# C) `10 * 2.0`
# D) `10 ** 0.5`
#
# **答案**：_____

# %% [markdown]
# ---
#
# ### 題組 B：比較運算子（6-10）
#
# #### 6. `5 == 5.0` 的結果是？
# A) True
# B) False
# C) TypeError
# D) None
#
# **答案**：_____
#
# ---
#
# #### 7. `"10" > "9"` 的結果是？
# A) True
# B) False
# C) TypeError
# D) 無法判斷
#
# **答案**：_____
#
# ---
#
# #### 8. 以下哪個是正確的連鎖比較？
# A) `10 < x < 20`
# B) `10 < x and x < 20`
# C) 兩者都正確
# D) 兩者都錯誤
#
# **答案**：_____
#
# ---
#
# #### 9. `not (5 > 3)` 的結果是？
# A) True
# B) False
# C) None
# D) SyntaxError
#
# **答案**：_____
#
# ---
#
# #### 10. `10 != 10` 的結果是？
# A) True
# B) False
# C) None
# D) TypeError
#
# **答案**：_____

# %% [markdown]
# ---
#
# ### 題組 C：邏輯運算子（11-15）
#
# #### 11. `True and False or True` 的結果是？
# A) True
# B) False
# C) None
# D) SyntaxError
#
# **答案**：_____
#
# ---
#
# #### 12. `not True and False` 的結果是？
# A) True
# B) False
# C) None
# D) SyntaxError
#
# **答案**：_____
#
# ---
#
# #### 13. 如果 `x = 0`，哪個表達式不會報錯？
# A) `10 / x`
# B) `x != 0 and 10 / x > 2`
# C) `10 / x > 2 and x != 0`
# D) 都會報錯
#
# **答案**：_____
#
# ---
#
# #### 14. 以下哪個是 False？
# A) `bool(1)`
# B) `bool("False")`
# C) `bool([])`
# D) `bool(-1)`
#
# **答案**：_____
#
# ---
#
# #### 15. `5 > 3 and 2 < 1` 的結果是？
# A) True
# B) False
# C) None
# D) TypeError
#
# **答案**：_____

# %% [markdown]
# ---
#
# ## Part II: 程式題（40 分）
#
# ### 程式題 1：判斷偶數（8 分）
#
# **題目**：判斷變數 `num` 是否為偶數，將結果存入 `is_even`。
#
# **要求**：只能使用一行程式碼（除了 print）

# %%
# 程式題 1
num = 42

# 在此撰寫你的程式碼（一行）
is_even = 

print(f"{num} 是偶數：{is_even}")  # 應輸出 True

# %% [markdown]
# ---
#
# ### 程式題 2：範圍判斷（8 分）
#
# **題目**：判斷 `score` 是否在 60-100 之間（含 60 和 100）。
#
# **要求**：使用連鎖比較

# %%
# 程式題 2
score = 75

# 在此撰寫你的程式碼
is_valid_score = 

print(f"分數有效：{is_valid_score}")  # 應輸出 True

# %% [markdown]
# ---
#
# ### 程式題 3：溫度判斷（8 分）
#
# **題目**：判斷溫度是否「舒適」（15°C ≤ temp < 28°C）**且** 濕度正常（humidity < 70）。

# %%
# 程式題 3
temperature = 22
humidity = 60

# 在此撰寫你的程式碼
is_comfortable = 

print(f"環境舒適：{is_comfortable}")  # 應輸出 True

# %% [markdown]
# ---
#
# ### 程式題 4：整除與取模（8 分）
#
# **題目**：將總秒數轉換為分鐘和秒。
#
# **範例**：125 秒 = 2 分鐘 5 秒

# %%
# 程式題 4
total_seconds = 125

# 在此撰寫你的程式碼
minutes = 
seconds = 

print(f"{total_seconds} 秒 = {minutes} 分鐘 {seconds} 秒")  # 應輸出：125 秒 = 2 分鐘 5 秒

# %% [markdown]
# ---
#
# ### 程式題 5：運算優先順序（8 分）
#
# **題目**：不使用括號，寫出表達式使結果為 50。
#
# **可用數字**：2, 3, 4, 5
# **可用運算子**：+, -, *, /, //, %, **
#
# **範例**（錯誤）：`2 + 3 * 4 + 5` = 19（不是 50）

# %%
# 程式題 5
# 在此撰寫你的表達式（不使用括號）
result = 

print(f"結果：{result}")  # 應輸出 50

# %% [markdown]
# ---
#
# ## 📝 答案與解析
#
# ### Part I: 選擇題答案
#
# | 題號 | 答案 | 解析 |
# |:----:|:----:|:-----|
# | 1 | B | 先算 5*2=10，再算 10+10=20 |
# | 2 | B | 整除：17÷5=3餘2，取商為3 |
# | 3 | B | 取模：17÷5=3餘2，取餘數為2 |
# | 4 | B | 右結合：先算 3**2=9，再算 2**9=512 |
# | 5 | B | `//` 是整數除法，回傳 int |
# | 6 | A | Python 允許不同數值型態比較 |
# | 7 | B | 字串按字典序比較，"1" < "9" |
# | 8 | C | Python 支援連鎖比較 |
# | 9 | B | `5 > 3` 為 True，取反為 False |
# | 10 | B | 10 等於 10，所以不等於為 False |
# | 11 | A | `False or True` = True |
# | 12 | B | `not True` = False，`False and False` = False |
# | 13 | B | 短路求值：x != 0 為 False，不執行後面 |
# | 14 | C | 空列表 [] 為 False |
# | 15 | B | `True and False` = False |
#
# ---
#
# ### Part II: 程式題答案
#
# #### 程式題 1

# %%
# 程式題 1 答案
num = 42
is_even = (num % 2 == 0)
print(f"{num} 是偶數：{is_even}")

# %% [markdown]
# #### 程式題 2

# %%
# 程式題 2 答案
score = 75
is_valid_score = (60 <= score <= 100)
print(f"分數有效：{is_valid_score}")

# %% [markdown]
# #### 程式題 3

# %%
# 程式題 3 答案
temperature = 22
humidity = 60
is_comfortable = (15 <= temperature < 28) and (humidity < 70)
print(f"環境舒適：{is_comfortable}")

# %% [markdown]
# #### 程式題 4

# %%
# 程式題 4 答案
total_seconds = 125
minutes = total_seconds // 60
seconds = total_seconds % 60
print(f"{total_seconds} 秒 = {minutes} 分鐘 {seconds} 秒")

# %% [markdown]
# #### 程式題 5

# %%
# 程式題 5 答案（多種可能）
# 方法 1: 2 + 3 * 4 ** 2 = 2 + 3 * 16 = 2 + 48 = 50
result = 2 + 3 * 4 ** 2

# 方法 2: 2 ** 5 + 3 * 4 + 2 = 32 + 12 + 2 = 46（不對）
# 方法 3: 5 * 2 ** 3 + 10（需要用到 10，不符合）

print(f"結果：{result}")

# %% [markdown]
# ---
#
# ## 📊 計分與評估
#
# ### 計分方式
# - **選擇題**：對 1 題得 4 分（共 60 分）
# - **程式題**：對 1 題得 8 分（共 40 分）
# - **總分**：100 分
#
# ### 成績評估
# - **90-100 分**：優秀！完全掌握運算子
# - **80-89 分**：良好！大部分概念清楚
# - **70-79 分**：及格！需加強練習
# - **60-69 分**：待加強！需重新學習部分內容
# - **< 60 分**：需重學！建議重看講義與範例
#
# ### 我的分數記錄
#
# ```
# 選擇題：____ / 60 分（對 ____ 題）
# 程式題：____ / 40 分（對 ____ 題）
# 總分：  ____ / 100 分
# 評級：  __________
# ```
#
# ---
#
# ## 🎯 錯題檢討
#
# ### 我答錯的題目
#
# 題號 ___：我的答案 ___，正確答案 ___
# 錯誤原因：
#
# 題號 ___：我的答案 ___，正確答案 ___
# 錯誤原因：
#
# ---
#
# ## 📚 複習建議
#
# ### 如果你在題組 A（算術）答錯
# - 複習 `01-lecture.ipynb` 範例 1-3
# - 重做 `04-exercises.ipynb` 習題 1-2, 9, 11
# - 重點：運算子優先順序、整除與取模
#
# ### 如果你在題組 B（比較）答錯
# - 複習 `01-lecture.ipynb` 範例 4
# - 重做 `04-exercises.ipynb` 習題 3, 5, 7-8
# - 重點：連鎖比較、字串比較
#
# ### 如果你在題組 C（邏輯）答錯
# - 複習 `01-lecture.ipynb` 範例 5-6
# - 重做 `04-exercises.ipynb` 習題 4, 6, 10
# - 重點：and/or/not、短路求值
#
# ### 如果程式題失分較多
# - 重做所有 `03-practice.ipynb` 練習
# - 參考 `05-solutions.ipynb` 學習解題思路
# - 多寫程式碼，培養手感
#
# ---
#
# ## ✅ 完成檢核
#
# 完成測驗後，請確認：
# - [ ] 已獨立完成所有題目
# - [ ] 已對照答案並計分
# - [ ] 已檢討錯題
# - [ ] 已規劃複習計畫（如需要）
# - [ ] 分數達到 70 分以上（可進入下一章）
#
# ---
#
# ## 🎓 結語
#
# 恭喜完成 Chapter 2 的所有學習內容！
#
# 如果測驗成績達標，你已經掌握：
# - ✅ Python 的所有基本運算子
# - ✅ 運算子優先順序
# - ✅ 複雜表達式的構建與求值
# - ✅ 短路求值的應用
#
# **下一步**：
# - 繼續學習 **Chapter 3: 輸入輸出與格式化**
# - 或開始 **Milestone 1: 簡易計算機** 整合練習
